# %%
# Importación de todas las librerias a utilizar.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
from collections import Counter
import scipy.stats as st
from scipy import optimize
import statsmodels.api as sm 
from statsmodels.nonparametric.kernel_density import KDEMultivariate
from sklearn.neighbors import KernelDensity
from sklearn.model_selection import GridSearchCV

# %%
data1=pd.read_csv('../Proyecto-Final-Finazas-P-blicas-2020/Ingresos.csv', index_col=[0],encoding="'latin-1'").fillna(0)
data1.head()
# Out:
#                                                     Total         Total.1  \
# Año                                                  1989            1990
# Total                                      22,458,426,771  26,231,070,842
# Impuestos                                     442,399,845     726,826,110
# Cuotas y Aportaciones de Seguridad Social   3,695,250,647   4,884,929,668
# Contribuciones de mejoras                               0               0
#
#                                                   Total.2         Total.3  \
# Año                                                  1991            1992
# Total                                      34,719,398,284  51,885,273,960
# Impuestos                                   1,150,208,251   1,584,250,856
# Cuotas y Aportaciones de Seguridad Social   4,316,625,823  10,814,737,266
# Contribuciones de mejoras                               0               0
#
#                                                   Total.4         Total.5  \
# Año                                                  1993            1994
# Total                                      68,140,995,275  90,271,575,407
# Impuestos                                   1,811,518,273   2,028,854,075
# Cuotas y Aportaciones de Seguridad Social  14,608,994,956  18,757,323,144
# Contribuciones de mejoras                               0               0
#
#                                                    Total.6          Total.7  \
# Año                                                   1995             1996
# Total                                      111,039,766,629  143,670,808,558
# Impuestos                                    2,385,840,559    3,239,804,409
# Cuotas y Aportaciones de Seguridad Social    8,873,933,306    9,124,233,428
# Contribuciones de mejoras                       72,480,713      104,882,758
#
#                                                    Total.8          Total.9  \
# Año                                                   1997             1998
# Total                                      189,829,410,773  254,742,222,245
# Impuestos                                    4,316,514,500    5,541,510,701
# Cuotas y Aportaciones de Seguridad Social   12,066,367,830   12,470,964,745
# Contribuciones de mejoras                      113,591,601       50,751,350
#
#                                            ...    Zacatecas.21  \
# Año                                        ...            2010
# Total                                      ...  23,538,033,677
# Impuestos                                  ...     266,806,715
# Cuotas y Aportaciones de Seguridad Social  ...               0
# Contribuciones de mejoras                  ...     141,141,773
#
#                                              Zacatecas.22    Zacatecas.23  \
# Año                                                  2011            2012
# Total                                      25,462,774,498  26,826,368,772
# Impuestos                                     308,009,310     475,899,794
# Cuotas y Aportaciones de Seguridad Social               0               0
# Contribuciones de mejoras                     222,072,360     248,019,867
#
#                                              Zacatecas.24    Zacatecas.25  \
# Año                                                  2013            2014
# Total                                      25,834,634,936  28,696,440,001
# Impuestos                                     503,813,608     442,717,540
# Cuotas y Aportaciones de Seguridad Social               0               0
# Contribuciones de mejoras                     277,989,932     148,044,614
#
#                                              Zacatecas.26    Zacatecas.27  \
# Año                                                  2015            2016
# Total                                      30,462,058,528  34,484,945,318
# Impuestos                                     375,551,421     424,203,834
# Cuotas y Aportaciones de Seguridad Social               0               0
# Contribuciones de mejoras                     108,179,219      99,531,027
#
#                                              Zacatecas.28    Zacatecas.29  \
# Año                                                  2017            2018
# Total                                      39,614,097,562  34,941,953,849
# Impuestos                                     970,802,081   1,042,394,304
# Cuotas y Aportaciones de Seguridad Social               0               0
# Contribuciones de mejoras                     146,430,400     119,077,563
#
#                                              Zacatecas.30
# Año                                                  2019
# Total                                      33,806,399,815
# Impuestos                                   1,192,542,875
# Cuotas y Aportaciones de Seguridad Social               0
# Contribuciones de mejoras                      27,175,416
#
# [5 rows x 992 columns]

# %%
data2=pd.read_csv('../Proyecto-Final-Finazas-P-blicas-2020/Egresos.csv', index_col=[0],encoding="'latin-1'").fillna(0)
data2.head()
# Out:
#                                    Total         Total.1         Total.2  \
# Año                                 1989            1990            1991
# Total                     22,458,426,771  26,231,070,842  34,719,398,284
# Servicios personales       4,590,245,370   6,203,746,096   8,969,618,712
# Materiales y suministros   1,051,656,204   1,627,346,184   1,706,133,188
# Servicios generales          356,005,451     483,824,355     785,545,359
#
#                                  Total.3         Total.4         Total.5  \
# Año                                 1992            1993            1994
# Total                     51,885,273,960  68,140,995,275  90,271,575,407
# Servicios personales      13,176,083,646  15,794,340,047  20,397,950,195
# Materiales y suministros   2,630,814,834   3,943,845,824   4,414,182,291
# Servicios generales        1,068,290,345   1,523,352,488   1,735,500,977
#
#                                   Total.6          Total.7          Total.8  \
# Año                                  1995             1996             1997
# Total                     111,039,766,629  143,670,808,558  189,829,410,773
# Servicios personales       29,052,010,311   45,572,228,732   60,166,883,050
# Materiales y suministros    3,676,942,369    2,594,437,876    3,384,230,958
# Servicios generales         2,129,980,304    4,721,824,363    6,510,017,654
#
#                                   Total.9  ...    Zacatecas.21  \
# Año                                  1998  ...            2010
# Total                     254,742,222,245  ...  23,538,033,677
# Servicios personales       69,355,668,540  ...   7,428,515,816
# Materiales y suministros    3,358,558,954  ...     183,642,314
# Servicios generales         6,804,562,683  ...     766,047,250
#
#                             Zacatecas.22    Zacatecas.23    Zacatecas.24  \
# Año                                 2011            2012            2013
# Total                     25,462,774,498  26,826,368,772  25,834,634,936
# Servicios personales       8,082,489,248   8,662,437,547   9,178,060,692
# Materiales y suministros     204,954,989     272,307,427     347,353,372
# Servicios generales          539,602,795     616,786,360     622,183,043
#
#                             Zacatecas.25    Zacatecas.26    Zacatecas.27  \
# Año                                 2014            2015            2016
# Total                     28,696,440,001  30,462,058,528  34,484,945,318
# Servicios personales       9,726,287,651  10,146,481,841  10,782,016,122
# Materiales y suministros     611,625,378     688,685,435     654,881,097
# Servicios generales          856,322,947     959,959,325     951,779,253
#
#                             Zacatecas.28    Zacatecas.29    Zacatecas.30
# Año                                 2017            2018            2019
# Total                     39,614,097,562  34,941,953,849  33,806,399,815
# Servicios personales      11,265,166,306  11,736,510,902  12,547,939,980
# Materiales y suministros     999,669,109     826,900,297     651,177,298
# Servicios generales        1,029,469,617   1,442,492,303   1,291,220,661
#
# [5 rows x 992 columns]

# %% [markdown]
# # MICHOACÁN

# %%
Michoacan_ingreso=data1.iloc[:,465:496]
Michoacan_egreso=data2.iloc[:,465:496]

# %%
#Creación Data Frame 'limpio' INGRESOS
ingresos = pd.DataFrame(index=data1.T.iloc[:,0][0:31], columns=['Total','Impuestos','Cuotas y Aportaciones de Seguridad Social',
                        'Contribuciones de mejoras','Derechos','Productos','Aprovechamientos','Participaciones federales',
                        'Aportaciones federales','Otros ingresos','Financiamiento','Disponibilidad inicial'])

ingresos['Total'] = [int([str(Michoacan_ingreso.iloc[1][i]).replace(',','') for i in range(31)][j]) 
                     for j in range(31)]
ingresos['Impuestos'] = [int([str(Michoacan_ingreso.iloc[2][i]).replace(',','') for i in range(31)][j]) 
                         for j in range(31)]
ingresos['Cuotas y Aportaciones de Seguridad Social'] = [int([str(Michoacan_ingreso.iloc[3][i]).replace(',','') for i in range(31)][j]) 
                                                         for j in range(31)]
ingresos['Contribuciones de mejoras'] = [int([str(Michoacan_ingreso.iloc[3][i]).replace(',','') for i in range(31)][j]) 
                                         for j in range(31)]
ingresos['Derechos'] = [int([str(Michoacan_ingreso.iloc[5][i]).replace(',','') for i in range(31)][j]) 
                        for j in range(31)]
ingresos['Productos'] = [int([str(Michoacan_ingreso.iloc[6][i]).replace(',','') for i in range(31)][j]) 
                         for j in range(31)]
ingresos['Aprovechamientos'] = [int([str(Michoacan_ingreso.iloc[7][i]).replace(',','') for i in range(31)][j]) 
                                for j in range(31)]
ingresos['Participaciones federales'] = [int([str(Michoacan_ingreso.iloc[8][i]).replace(',','') for i in range(31)][j]) 
                                         for j in range(31)]
ingresos['Aportaciones federales'] = [int([str(Michoacan_ingreso.iloc[9][i]).replace(',','') for i in range(31)][j]) 
                                      for j in range(31)]
ingresos['Otros ingresos'] = [int([str(Michoacan_ingreso.iloc[10][i]).replace(',','') for i in range(31)][j]) 
                              for j in range(31)]
ingresos['Financiamiento'] = [int([str(Michoacan_ingreso.iloc[11][i]).replace(',','') for i in range(31)][j]) 
                              for j in range(31)]
ingresos['Disponibilidad inicial'] = [int([str(Michoacan_ingreso.iloc[12][i]).replace(',','') for i in range(31)][j]) 
                                      for j in range(31)]

# ingresos.set_index('Año', inplace=True)

ingresos
# Out:
#             Total   Impuestos  Cuotas y Aportaciones de Seguridad Social  \
# Año
# 1989    375142272     7493961                                   18601695
# 1990    558295504    11036654                                   58299770
# 1991    781573567    14879485                                   29378447
# 1992   1101265174    21434688                                   41464904
# 1993   1241769709    20363018                                   18950181
# 1994   2877065470    20678486                                   32519374
# 1995   3525088581    23282632                                          0
# 1996   4665775408    32021464                                          0
# 1997   6718004957    41393162                                          0
# 1998   9575218253    46686936                                          0
# 1999  11889351610    76883289                                          0
# 2000  15442763598    77082676                                          0
# 2001  17889249973    98036404                                          0
# 2002  19553903519   113193722                                          0
# 2003  22609164605   308529361                                          0
# 2004  23974974805   327325101                                          0
# 2005  27408719938   401302268                                          0
# 2006  30285055153   534135629                                          0
# 2007  36700349833   624551387                                          0
# 2008  40218079098   619626684                                          0
# 2009  44224259188   741150142                                          0
# 2010  48321358300   741571265                                          0
# 2011  53751245849   917755180                                          0
# 2012  52758184477  1269946673                                          0
# 2013  58040153557  1669200631                                          0
# 2014  61732510923  1578484290                                          0
# 2015  62740715681   849992647                                          0
# 2016  68479297625  1061618573                                          0
# 2017  71829276721   903294175                                          0
# 2018  79944803605  1229690777                                          0
# 2019  79978749718  1935394024                                          0
#
#       Contribuciones de mejoras    Derechos  Productos  Aprovechamientos  \
# Año
# 1989                   18601695    11396247    5675268           7293421
# 1990                   58299770    19818073   23331136          10330785
# 2018      3047887707                       0
# 2019               0                       0

# %%
#Creación Data Frame 'limpio' EGRESOS
egresos = pd.DataFrame(index=data1.T.iloc[:,0][0:31], columns=['Total','Servicios personales','Materiales y suministros',
                        'Servicios generales','Transferencias, asignaciones, subsidios y otras ayudas',
                        'Bienes muebles, inmuebles e intangibles','Inversión pública',
                        'Inversiones financieras y otras provisiones',
                        'Recursos asignados a municipios','Otros egresos','Deuda pública','Disponibilidad final'])

egresos['Total'] = [int([str(Michoacan_egreso.iloc[1][i]).replace(',','') for i in range(31)][j]) 
                     for j in range(31)]
egresos['Servicios personales'] = [int([str(Michoacan_egreso.iloc[2][i]).replace(',','') for i in range(31)][j]) 
                         for j in range(31)]
egresos['Materiales y suministros'] = [int([str(Michoacan_egreso.iloc[3][i]).replace(',','') for i in range(31)][j]) 
                                                         for j in range(31)]
egresos['Servicios generales'] = [int([str(Michoacan_egreso.iloc[3][i]).replace(',','') for i in range(31)][j]) 
                                         for j in range(31)]
egresos['Transferencias, asignaciones, subsidios y otras ayudas'] = [int([str(Michoacan_egreso.iloc[5][i]).replace(',','') for i in range(31)][j]) 
                        for j in range(31)]
egresos['Bienes muebles, inmuebles e intangibles'] = [int([str(Michoacan_egreso.iloc[6][i]).replace(',','') for i in range(31)][j]) 
                                                      for j in range(31)]
egresos['Inversión pública'] = [int([str(Michoacan_egreso.iloc[7][i]).replace(',','') for i in range(31)][j]) 
                                for j in range(31)]
egresos['Inversiones financieras y otras provisiones'] = [int([str(Michoacan_egreso.iloc[8][i]).replace(',','') for i in range(31)][j]) 
                                         for j in range(31)]
egresos['Recursos asignados a municipios'] = [int([str(Michoacan_egreso.iloc[9][i]).replace(',','') for i in range(31)][j]) 
                                      for j in range(31)]
egresos['Otros egresos'] = [int([str(Michoacan_egreso.iloc[10][i]).replace(',','') for i in range(31)][j]) 
                              for j in range(31)]
egresos['Deuda pública'] = [int([str(Michoacan_egreso.iloc[11][i]).replace(',','') for i in range(31)][j]) 
                              for j in range(31)]
egresos['Disponibilidad final'] = [int([str(Michoacan_egreso.iloc[12][i]).replace(',','') for i in range(31)][j]) 
                                      for j in range(31)]

# ingresos.set_index('Año', inplace=True)

egresos
# Out:
#             Total  Servicios personales  Materiales y suministros  \
# Año
# 1989    375142272             111832000                  22831500
# 1990    558295504             174722451                  22116038
# 1991    781573567             241579941                  25741505
# 1992   1101265174             324151312                  36858039
# 1993   1241769709             385048456                  38648636
# 1994   2877065470            1793048787                  55413415
# 1995   3525088581            2194371317                  51367672
# 1996   4665775408            3026901138                  57522413
# 1997   6718004957            4156345406                 175103487
# 1998   9575218253            5483372522                 243394653
# 1999  11889351610            6642551000                 265819562
# 2000  15442763598            8098183076                 317267104
# 2001  17889249973            8761990073                 526614704
# 2002  19553903519           10154325528                 455018895
# 2003  22609164605           11210338896                 424115827
# 2004  23974974805           12062759760                 424960544
# 2005  27408719938           13252017125                 378768620
# 2006  30285055153           14707463858                 405673320
# 2007  36700349833           16320022468                 522864979
# 2008  40218079098           18151122284                 375870667
# 2009  44224259188           19399427565                 610127723
# 2010  48321358300           20803139028                 696173059
# 2008                                            0
# 2009                                            0
# 2010                                            0
# 2011                                            0
# 2012                                            0
# 2013                                            0
# 2014                                            0
# 2015                                    270550090
# 2016                                    120350449
# 2017                                     83912803
# 2018                                     71415000
# 2019                                     82625000
#
#       Recursos asignados a municipios  Otros egresos  Deuda pública  \
# Año
# 1989                                0              0       24961300
# 1990                                0              0       61686273
# 1991                        148361050              0       44730463
# 1992                        200297352              0       11442181
# 1993                                0              0        9102452
# 1994                        266352898              0       11022921
# 1995                        375834989              0       36730637
# 1996                        484877673              0       25971773
# 1997                        659650636              0       22644987
# 1998                       1548404856              0       14723082
# 1999                       2275226986              0       11317585
# 2000                       2804362583              0       14457268
# 2001                       3286106531              0       12223634
# 2002                       3421885255              0       32932617
# 2003                       3717228248              0      151930335
# 2004                       3934689966              0      301018540
# 2005                       4398707051              0      440577685
# 2006                       4959871903              0      500261484
# 2007                       5277632801              0      649754337
# 2008                       6406828849              0      615171684
# 2009                       6508768899              0      826007067
# 2010                       6768023482              0     2216866838
# 2011                       7697578547              0     2562090627
# 2012                       7569179051              0     3301430719
# 2013                       8231401775              0     5194948968
# 2014                       8752503926              0     1512281230
# 2015                      10904895347              0     1536531210
# 2016                      12666284441              0     1925864048
# 2017                      13412389711              0     2667669528
# 2018                      13254377196              0     2794360020
# 2019                      13708004747              0     2516723484
#
#       Disponibilidad final
# Año
# 1989                905072
# 1990              12349543
# 1991                     0
# 1992                     0
# 1993                     0
# 1994                     0
# 1995                     0
# 1996              66264663
# 1997               4414453
# 1998              12876299
# 1999              13580653
# 2000             167781146
# 2001                     0
# 2002                     0
# 2003             321150416
# 2004                     0
# 2005            1116586065
# 2006                     0
# 2007            1437244199
# 2008             731161692
# 2009                     0
# 2010                     0
# 2011            1402176772
# 2012            1692245431
# 2013             108093785
# 2014            1064644259
# 2015                     0
# 2016                     0
# 2017                     0
# 2018            4948883533
# 2019            1113836590

# %%
ingresos.plot(figsize=(20,10));

# %%
egresos.plot(figsize=(20,10));

# %% [markdown]
# # Simulación Total Ingresos

# %%
# Obtenemos el rendimiento simple
Total_ingresos=ingresos.drop(columns=ingresos.columns[1:12])
Ri_ingresos = (Total_ingresos.pct_change(1).iloc[1:])
# Obtenemos su media y desviación estándar de los rendimientos
mu_R_ingresos = Ri_ingresos.mean()[0]
sigma_R_ingresos = Ri_ingresos.std()[0]
Ri_ingresos.plot()
Ri_ingresos.tail()
# Out:
#          Total
# Año
# 2015  0.016332
# 2016  0.091465
# 2017  0.048920
# 2018  0.112984
# 2019  0.000425

# %%
from datetime import date
# Encontrar la fecha de hoy en formato timestamp
today = '2020'
# Obtener fecha de cierre de la opción a valuar
expiry = '2030'
nscen = 5
# Generar rangos de fechas de días hábiles
dates = (2020,2021,2022,2023,2024,2025,2026,2027,2028,2029,2030)
ndays = len(dates)

# %%
# Simular los rendimientos
# Rendimiento diario 
dt_ingresos = .1
# Z ~ N(0,1) normal estándar (ndays, nscen)
Z_ingresos = np.random.randn(ndays, nscen)

# Simulación normal de los rendimientos
Ri_dt_ingresos = pd.DataFrame(mu_R_ingresos * dt_ingresos + Z_ingresos * sigma_R_ingresos * np.sqrt(dt_ingresos), index=dates)

# %%
# Simulación del precio
S_0_ingresos = Total_ingresos.iloc[-1,0]
S_T_ingresos = S_0_ingresos*(1+Ri_dt_ingresos).cumprod()
S_T_ingresos

Simulacion_ingreso=pd.DataFrame(index=np.arange(1989,2031),columns=['Total','Total1','Total2','Total3','Total4'])
Simulacion_ingreso['Total']= np.array(pd.concat([Total_ingresos.iloc[:,0],S_T_ingresos.iloc[:,0]]))
Simulacion_ingreso['Total1']= np.array(pd.concat([Total_ingresos.iloc[:,0],S_T_ingresos.iloc[:,1]]))
Simulacion_ingreso['Total2']= np.array(pd.concat([Total_ingresos.iloc[:,0],S_T_ingresos.iloc[:,2]]))
Simulacion_ingreso['Total3']= np.array(pd.concat([Total_ingresos.iloc[:,0],S_T_ingresos.iloc[:,3]]))
Simulacion_ingreso['Total4']= np.array(pd.concat([Total_ingresos.iloc[:,0],S_T_ingresos.iloc[:,4]]))

# Se muestran los precios simulados con los precios descargados
plt.figure(figsize=(18,6))
plt.plot(Simulacion_ingreso.iloc[:,0][0:31],'g',label='Datos originales')
plt.plot(Simulacion_ingreso.iloc[:,0][30:42],'orange',label='Simulación 1')
plt.plot(Simulacion_ingreso.iloc[:,1][30:42],'black',label='Simulación 2')
plt.plot(Simulacion_ingreso.iloc[:,2][30:42],'purple',label='Simulación 3')
plt.plot(Simulacion_ingreso.iloc[:,3][30:42],'brown',label='Simulación 4')
plt.plot(Simulacion_ingreso.iloc[:,4][30:42],'gray',label='Simulación 5')
plt.plot(2019,Total_ingresos.iloc[-1],'ob',label='Ultimo registro de ingreso')
plt.plot(2020,7.5914903948e10,'or',label='Ingreso real 2020 Michoacán')
plt.xlabel('Año')
plt.ylabel('Ingreso a escala')
plt.title('Simulación de precios usando rendimiento simple');
plt.legend();
plt.show()

# %%
print('Ingreso real Michoacán 2019=',format(int(Total_ingresos.iloc[-1]),'0,.1f'))
print('Ingreso real Michoacán 2020=',format(7.5914903948e10,'0,.1f'))
print('Ingreso simulación 1 2020 Michoacán =',format(int(Simulacion_ingreso.iloc[:,0][31:32]),'0,.1f'))
print('Ingreso simulación 2 2020 Michoacán =',format(int(Simulacion_ingreso.iloc[:,1][31:32]),'0,.1f'))
print('Ingreso simulación 3 2020 Michoacán =',format(int(Simulacion_ingreso.iloc[:,2][31:32]),'0,.1f'))
print('Ingreso simulación 4 2020 Michoacán =',format(int(Simulacion_ingreso.iloc[:,3][31:32]),'0,.1f'))
print('Ingreso simulación 5 2020 Michoacán =',format(int(Simulacion_ingreso.iloc[:,4][31:32]),'0,.1f'))
# Out:
# Ingreso real Michoacán 2019= 79,978,749,718.0
# Ingreso real Michoacán 2020= 75,914,903,948.0
# Ingreso simulación 1 2020 Michoacán = 83,308,923,388.0
# Ingreso simulación 2 2020 Michoacán = 83,749,902,498.0
# Ingreso simulación 3 2020 Michoacán = 74,601,942,927.0
# Ingreso simulación 4 2020 Michoacán = 84,313,669,251.0
# Ingreso simulación 5 2020 Michoacán = 85,392,964,068.0

# %%
print('Error simulación 1 2020 Michoacán =',np.abs(int(Simulacion_ingreso.iloc[:,0][31:32])/7.5914903948e10-1)*100,'%')
print('Error simulación 2 2020 Michoacán =',np.abs(int(Simulacion_ingreso.iloc[:,1][31:32])/7.5914903948e10-1)*100,'%')
print('Error simulación 3 2020 Michoacán =',np.abs(int(Simulacion_ingreso.iloc[:,2][31:32])/7.5914903948e10-1)*100,'%')
print('Error simulación 4 2020 Michoacán =',np.abs(int(Simulacion_ingreso.iloc[:,3][31:32])/7.5914903948e10-1)*100,'%')
print('Error simulación 5 2020 Michoacán =',np.abs(int(Simulacion_ingreso.iloc[:,4][31:32])/7.5914903948e10-1)*100,'%')
# Out:
# Error simulación 1 2020 Michoacán = 9.739878542248759 %
# Error simulación 2 2020 Michoacán = 10.320764622671197 %
# Error simulación 3 2020 Michoacán = 1.7295168046308151 %
# Error simulación 4 2020 Michoacán = 11.06339449333027 %
# Error simulación 5 2020 Michoacán = 12.485111127180314 %

# %% [markdown]
# # Simulación Deuda Pública Egresos

# %%
# Obtenemos el rendimiento simple
Total_egresos=egresos.drop(columns=egresos.columns[0:10]).drop(columns=egresos.columns[11])
Ri_egresos = (Total_egresos.pct_change(1).iloc[1:])
# Obtenemos su media y desviación estándar de los rendimientos
mu_R_egresos = Ri_egresos.mean()[0]
sigma_R_egresos = Ri_egresos.std()[0]
Ri_egresos.plot()
Ri_egresos.tail()
# Out:
#       Deuda pública
# Año
# 2015       0.016035
# 2016       0.253384
# 2017       0.385181
# 2018       0.047491
# 2019      -0.099356

# %%
from datetime import date
# Encontrar la fecha de hoy en formato timestamp
today = '2020'
# Obtener fecha de cierre de la opción a valuar
expiry = '2030'
nscen = 5
# Generar rangos de fechas de días hábiles
dates = (2020,2021,2022,2023,2024,2025,2026,2027,2028,2029,2030)
ndays = len(dates)

# %%
# Simular los rendimientos
# Rendimiento diario 
dt_egresos = .1
# Z ~ N(0,1) normal estándar (ndays, nscen)
Z_egresos = np.random.randn(ndays, nscen)

# Simulación normal de los rendimientos
Ri_dt_egresos = pd.DataFrame(mu_R_egresos * dt_egresos + Z_egresos * sigma_R_egresos * np.sqrt(dt_egresos), index=dates)

# %%
# Simulación del precio
S_0_egresos = Total_egresos.iloc[-1,0]
S_T_egresos = S_0_egresos*(1+Ri_dt_egresos).cumprod()
S_T_egresos

Simulacion_egreso=pd.DataFrame(index=np.arange(1989,2031),columns=['Total','Total1','Total2','Total3','Total4'])
Simulacion_egreso['Total']= np.array(pd.concat([Total_egresos.iloc[:,0],S_T_egresos.iloc[:,0]]))
Simulacion_egreso['Total1']= np.array(pd.concat([Total_egresos.iloc[:,0],S_T_egresos.iloc[:,1]]))
Simulacion_egreso['Total2']= np.array(pd.concat([Total_egresos.iloc[:,0],S_T_egresos.iloc[:,2]]))
Simulacion_egreso['Total3']= np.array(pd.concat([Total_egresos.iloc[:,0],S_T_egresos.iloc[:,3]]))
Simulacion_egreso['Total4']= np.array(pd.concat([Total_egresos.iloc[:,0],S_T_egresos.iloc[:,4]]))

# Se muestran los precios simulados con los precios descargados
plt.figure(figsize=(18,6))
plt.plot(Simulacion_egreso.iloc[:,0][0:31],'g',label='Datos originales')
plt.plot(Simulacion_egreso.iloc[:,0][30:42],'orange',label='Simulación 1')
plt.plot(Simulacion_egreso.iloc[:,1][30:42],'black',label='Simulación 2')
plt.plot(Simulacion_egreso.iloc[:,2][30:42],'purple',label='Simulación 3')
plt.plot(Simulacion_egreso.iloc[:,3][30:42],'brown',label='Simulación 4')
plt.plot(Simulacion_egreso.iloc[:,4][30:42],'gray',label='Simulación 5')
plt.plot(2019,Total_egresos.iloc[-1],'ob',label='Ultimo registro de egreso')
plt.plot(2020,3.006855732e9,'or',label='Egreso real 2020 Michoacán')
plt.xlabel('Año')
plt.ylabel('Egreso a escala')
plt.title('Simulación de precios usando rendimiento simple');
plt.legend();
plt.show()

# %%
print('Egreso real Michoacán 2019=',format(int(Total_egresos.iloc[-1]),'0,.1f'))
print('Egreso real Michoacán 2020=',format(3.006855732e9,'0,.1f'))
print('Egreso simulación 1 2020 Michoacán =',format(int(Simulacion_egreso.iloc[:,0][31:32]),'0,.1f'))
print('Egreso simulación 2 2020 Michoacán =',format(int(Simulacion_egreso.iloc[:,1][31:32]),'0,.1f'))
print('Egreso simulación 3 2020 Michoacán =',format(int(Simulacion_egreso.iloc[:,2][31:32]),'0,.1f'))
print('Egreso simulación 4 2020 Michoacán =',format(int(Simulacion_egreso.iloc[:,3][31:32]),'0,.1f'))
print('Egreso simulación 5 2020 Michoacán =',format(int(Simulacion_egreso.iloc[:,4][31:32]),'0,.1f'))
# Out:
# Egreso real Michoacán 2019= 2,516,723,484.0
# Egreso real Michoacán 2020= 3,006,855,732.0
# Egreso simulación 1 2020 Michoacán = 3,092,477,307.0
# Egreso simulación 2 2020 Michoacán = 3,810,130,892.0
# Egreso simulación 3 2020 Michoacán = 3,327,614,780.0
# Egreso simulación 4 2020 Michoacán = 2,575,087,942.0
# Egreso simulación 5 2020 Michoacán = 3,084,753,857.0

# %%
print('Error simulación 1 2020 Michoacán =',np.abs(int(Simulacion_egreso.iloc[:,0][31:32])/3.006855732e9-1)*100,'%')
print('Error simulación 2 2020 Michoacán =',np.abs(int(Simulacion_egreso.iloc[:,1][31:32])/3.006855732e9-1)*100,'%')
print('Error simulación 3 2020 Michoacán =',np.abs(int(Simulacion_egreso.iloc[:,2][31:32])/3.006855732e9-1)*100,'%')
print('Error simulación 4 2020 Michoacán =',np.abs(int(Simulacion_egreso.iloc[:,3][31:32])/3.006855732e9-1)*100,'%')
print('Error simulación 5 2020 Michoacán =',np.abs(int(Simulacion_egreso.iloc[:,4][31:32])/3.006855732e9-1)*100,'%')
# Out:
# Error simulación 1 2020 Michoacán = 2.8475451644981 %
# Error simulación 2 2020 Michoacán = 26.714788855722848 %
# Error simulación 3 2020 Michoacán = 10.66759022012167 %
# Error simulación 4 2020 Michoacán = 14.359444831522094 %
# Error simulación 5 2020 Michoacán = 2.5906838220065342 %

# %% [markdown]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
#
# <footer id="attribution" style="float:right; color:#808080; background:#fff;">
# Created with Jupyter by Luis Carlos Alvarado Garnica & Miguel de Jesús Aguirre Orozco.
# </footer>
